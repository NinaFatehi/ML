# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Build a regression tree using sklearn library

# %%
data = pd.read_csv("real_estate_data.csv")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     511 non-null    float64
#  1   ZN       511 non-null    float64
#  2   INDUS    511 non-null    float64
#  3   CHAS     511 non-null    int64
#  4   NOX      511 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      511 non-null    float64
#  7   DIS      511 non-null    float64
#  8   RAD      511 non-null    int64
#  9   TAX      511 non-null    int64
#  10  PTRATIO  511 non-null    float64
#  11  B        511 non-null    float64
#  12  LSTAT    511 non-null    float64
#  13  MEDV     511 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 56.0 KB

# %%
data.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(["MEDV"], axis=1), data["MEDV"], test_size=0.3, random_state=41)

# %%
X_train.shape
# Out:
# (354, 13)

# %%
X_test.shape
# Out:
# (152, 13)

# %%
rt = DecisionTreeRegressor(criterion="squared_error")

# %%
rt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
yhat = rt.predict(X_test)

# %%
pd.DataFrame({"True Labels": y_test, "Predicted Labels": yhat})
# Out:
#      True Labels  Predicted Labels
# 162         50.0              50.0
# 363         16.8              17.7
# 500         16.8              21.2
# 304         36.1              33.2
# 198         34.6              32.7
# ..           ...               ...
# 271         25.2              24.8
# 38          24.7              20.3
# 229         31.5              29.0
# 399          6.3              12.8
# 362         20.8              15.3
#
# [152 rows x 2 columns]

# %%
## It indicated the coefficient of determination
rt.score(X_test, y_test)
# Out:
# 0.7171717900120664

# %% [markdown]
# # Build a regression tree Using snapml library

# %%
pip install snapml
# Out:
# Requirement already satisfied: snapml in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (1.14.1)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (from snapml) (1.2.2)
# Requirement already satisfied: numpy>=1.21.3 in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (from snapml) (1.23.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (from snapml) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (from scikit-learn->snapml) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\tensorflow__\lib\site-packages (from scikit-learn->snapml) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import snapml

# %%
trip_data = pd.read_csv("yellow_tripdata_2016-01.csv")

# %%
trip_data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
# 2         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 4         2  2016-01-01 00:00:00   2016-01-01 00:00:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.981842         40.732407             2
# 1                  N         -73.944473         40.716679             1
# 2                  N         -73.950272         40.788925             1
# 3                  N         -73.962242         40.657333             2
# 4                  N         -73.977264         40.758514             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          7.5    0.5      0.5         0.0           0.0
# 1         18.0    0.5      0.5         0.0           0.0
# 2         33.0    0.5      0.5         0.0           0.0
# 3         16.5    0.0      0.5         0.0           0.0
# 4          8.0    0.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3           8.8
# 1                    0.3          19.3
# 2                    0.3          34.3
# 3                    0.3          17.3
# 4                    0.3           8.8

# %%
#trip_data.info

# %%
trip_data = trip_data[trip_data["tip_amount"]>0]

# %%
#trip_data.info

# %%
trip_data = trip_data[trip_data["tip_amount"] <= trip_data["fare_amount"]]

# %%
trip_data = trip_data[(trip_data["fare_amount"] >=1) & (trip_data["fare_amount"] <200)]

# %%
trip_data.shape
# Out:
# (6920930, 19)

# %%
trip_data.drop(["total_amount"], inplace=True, axis = 1)

# %%
trip_data.shape
# Out:
# (6920930, 18)

# %%
trip_data["tpep_pickup_datetime"] = pd.to_datetime(trip_data["tpep_pickup_datetime"])

# %%
trip_data.head()
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 11         2  2016-01-01 00:00:03   2016-01-01 00:15:49                6
# 13         1  2016-01-01 00:00:04   2016-01-01 00:14:32                1
# 14         1  2016-01-01 00:00:05   2016-01-01 00:14:27                2
# 17         1  2016-01-01 00:00:06   2016-01-01 00:04:44                1
# 18         2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
#
#     trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 11           2.43        -73.969330        40.763538           1
# 13           3.70        -74.004303        40.742241           1
# 14           2.20        -73.991997        40.718578           1
# 17           1.70        -73.982101        40.774696           1
# 18           1.38        -73.994843        40.718498           1
#
#    store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 11                  N         -73.995689         40.744251             1
# 13                  N         -74.007362         40.706936             1
# 14                  N         -74.005135         40.739944             1
# 17                  Y         -73.970940         40.796707             1
# 18                  N         -73.989807         40.734230             1
#
#     fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 11         12.0    0.5      0.5        3.99           0.0
# 13         14.0    0.5      0.5        3.05           0.0
# 14         11.0    0.5      0.5        1.50           0.0
# 17          7.0    0.5      0.5        1.65           0.0
# 18          7.0    0.5      0.5        1.66           0.0
#
#     improvement_surcharge
# 11                    0.3
# 13                    0.3
# 14                    0.3
# 17                    0.3
# 18                    0.3

# %%
trip_data.reset_index(inplace=True)

# %%
trip_data.drop(["index"], axis=1, inplace=True)

# %%
trip_data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2016-01-01 00:00:03   2016-01-01 00:15:49                6
# 1               1  2016-01-01 00:00:04   2016-01-01 00:14:32                1
# 2               1  2016-01-01 00:00:05   2016-01-01 00:14:27                2
# 3               1  2016-01-01 00:00:06   2016-01-01 00:04:44                1
# 4               2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
# ...           ...                  ...                   ...              ...
# 6920925         2  2016-01-31 21:28:59   2016-01-31 22:01:58                1
# 6920926         2  2016-01-31 22:36:41   2016-01-31 22:45:04                1
# 6920927         2  2016-01-31 22:53:00   2016-01-31 22:59:37                1
# 6920928         2  2016-01-31 23:00:11   2016-01-31 23:12:08                1
# 6920929         1  2016-01-05 06:21:44   2016-03-28 12:54:26                1
#
#          trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0                 2.43        -73.969330        40.763538           1
# 1                 3.70        -74.004303        40.742241           1
# 2                 2.20        -73.991997        40.718578           1
# 3                 1.70        -73.982101        40.774696           1
# 4                 1.38        -73.994843        40.718498           1
# ...                ...               ...              ...         ...
# 6920925           7.83        -74.002953        40.750481           1
# 6920926           2.50        -74.009277        40.717049           1
# 6920927           1.68        -74.003578        40.750751           1
# 6920928           2.65        -74.002159        40.734852           1
# 6920929           2.10        -73.948067        40.776531           1
#
#         store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                        N         -73.995689         40.744251             1
# 1                        N         -74.007362         40.706936             1
# 2                        N         -74.005135         40.739944             1
# 3                        Y         -73.970940         40.796707             1
# 4                        N         -73.989807         40.734230             1
# ...                    ...                ...               ...           ...
# 6920925                  N         -73.958153         40.656689             1
# 6920926                  N         -73.994637         40.750488             1
# 6920927                  N         -74.002159         40.734909             1
# 6920928                  N         -73.999680         40.761669             1
# 6920929                  N         -73.978188         40.777435             1
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0               12.0    0.5      0.5        3.99           0.0
# 1               14.0    0.5      0.5        3.05           0.0
# 2               11.0    0.5      0.5        1.50           0.0
# 3                7.0    0.5      0.5        1.65           0.0
# 4                7.0    0.5      0.5        1.66           0.0
# ...              ...    ...      ...         ...           ...
# 6920925         29.0    0.5      0.5        5.00           0.0
# 6920926          9.5    0.5      0.5        2.16           0.0
# 6920927          7.0    0.5      0.5        1.00           0.0
# 6920928         11.0    0.5      0.5        1.00           0.0
# 6920929         11.5    0.0      0.5        2.45           0.0
#
#          improvement_surcharge
# 0                          0.3
# 1                          0.3
# 2                          0.3
# 3                          0.3
# 4                          0.3
# ...                        ...
# 6920925                    0.3
# 6920926                    0.3
# 6920927                    0.3
# 6920928                    0.3
# 6920929                    0.3
#
# [6920930 rows x 18 columns]

# %%
trip_data["tpep_pickup_datetime"] = pd.to_datetime(trip_data["tpep_pickup_datetime"])
trip_data["tpep_dropoff_datetime"] = pd.to_datetime(trip_data["tpep_dropoff_datetime"])

# %%
trip_data.drop(["pickup_longitude", "dropoff_longitude", "pickup_latitude", "dropoff_latitude"], axis=1, inplace=True)

# %%
trip_data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2016-01-01 00:00:03   2016-01-01 00:15:49                6
# 1               1  2016-01-01 00:00:04   2016-01-01 00:14:32                1
# 2               1  2016-01-01 00:00:05   2016-01-01 00:14:27                2
# 3               1  2016-01-01 00:00:06   2016-01-01 00:04:44                1
# 4               2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
# ...           ...                  ...                   ...              ...
# 6920925         2  2016-01-31 21:28:59   2016-01-31 22:01:58                1
# 6920926         2  2016-01-31 22:36:41   2016-01-31 22:45:04                1
# 6920927         2  2016-01-31 22:53:00   2016-01-31 22:59:37                1
# 6920928         2  2016-01-31 23:00:11   2016-01-31 23:12:08                1
# 6920929         1  2016-01-05 06:21:44   2016-03-28 12:54:26                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  payment_type  \
# 0                 2.43           1                  N             1
# 1                 3.70           1                  N             1
# 2                 2.20           1                  N             1
# 3                 1.70           1                  Y             1
# 4                 1.38           1                  N             1
# ...                ...         ...                ...           ...
# 6920925           7.83           1                  N             1
# 6920926           2.50           1                  N             1
# 6920927           1.68           1                  N             1
# 6920928           2.65           1                  N             1
# 6920929           2.10           1                  N             1
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0               12.0    0.5      0.5        3.99           0.0
# 1               14.0    0.5      0.5        3.05           0.0
# 2               11.0    0.5      0.5        1.50           0.0
# 3                7.0    0.5      0.5        1.65           0.0
# 4                7.0    0.5      0.5        1.66           0.0
# ...              ...    ...      ...         ...           ...
# 6920925         29.0    0.5      0.5        5.00           0.0
# 6920926          9.5    0.5      0.5        2.16           0.0
# 6920927          7.0    0.5      0.5        1.00           0.0
# 6920928         11.0    0.5      0.5        1.00           0.0
# 6920929         11.5    0.0      0.5        2.45           0.0
#
#          improvement_surcharge
# 0                          0.3
# 1                          0.3
# 2                          0.3
# 3                          0.3
# 4                          0.3
# ...                        ...
# 6920925                    0.3
# 6920926                    0.3
# 6920927                    0.3
# 6920928                    0.3
# 6920929                    0.3
#
# [6920930 rows x 14 columns]

# %%
trip_data = pd.get_dummies(trip_data, columns=["store_and_fwd_flag"])

# %%
trip_data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2016-01-01 00:00:03   2016-01-01 00:15:49                6
# 1               1  2016-01-01 00:00:04   2016-01-01 00:14:32                1
# 2               1  2016-01-01 00:00:05   2016-01-01 00:14:27                2
# 3               1  2016-01-01 00:00:06   2016-01-01 00:04:44                1
# 4               2  2016-01-01 00:00:06   2016-01-01 00:07:14                1
# ...           ...                  ...                   ...              ...
# 6920925         2  2016-01-31 21:28:59   2016-01-31 22:01:58                1
# 6920926         2  2016-01-31 22:36:41   2016-01-31 22:45:04                1
# 6920927         2  2016-01-31 22:53:00   2016-01-31 22:59:37                1
# 6920928         2  2016-01-31 23:00:11   2016-01-31 23:12:08                1
# 6920929         1  2016-01-05 06:21:44   2016-03-28 12:54:26                1
#
#          trip_distance  RatecodeID  payment_type  fare_amount  extra  mta_tax  \
# 0                 2.43           1             1         12.0    0.5      0.5
# 1                 3.70           1             1         14.0    0.5      0.5
# 2                 2.20           1             1         11.0    0.5      0.5
# 3                 1.70           1             1          7.0    0.5      0.5
# 4                 1.38           1             1          7.0    0.5      0.5
# ...                ...         ...           ...          ...    ...      ...
# 6920925           7.83           1             1         29.0    0.5      0.5
# 6920926           2.50           1             1          9.5    0.5      0.5
# 6920927           1.68           1             1          7.0    0.5      0.5
# 6920928           2.65           1             1         11.0    0.5      0.5
# 6920929           2.10           1             1         11.5    0.0      0.5
#
#          tip_amount  tolls_amount  improvement_surcharge  \
# 0              3.99           0.0                    0.3
# 1              3.05           0.0                    0.3
# 2              1.50           0.0                    0.3
# 3              1.65           0.0                    0.3
# 4              1.66           0.0                    0.3
# ...             ...           ...                    ...
# 6920925        5.00           0.0                    0.3
# 6920926        2.16           0.0                    0.3
# 6920927        1.00           0.0                    0.3
# 6920928        1.00           0.0                    0.3
# 6920929        2.45           0.0                    0.3
#
#          store_and_fwd_flag_N  store_and_fwd_flag_Y
# 0                           1                     0
# 1                           1                     0
# 2                           1                     0
# 3                           0                     1
# 4                           1                     0
# ...                       ...                   ...
# 6920925                     1                     0
# 6920926                     1                     0
# 6920927                     1                     0
# 6920928                     1                     0
# 6920929                     1                     0
#
# [6920930 rows x 15 columns]

# %%
X = trip_data.drop(["tip_amount"], axis=1)

# %%
X = trip_data.drop(["tpep_pickup_datetime", "tpep_dropoff_datetime"], axis=1)

# %%
X.shape
# Out:
# (6920930, 13)

# %%
X
# Out:
#          VendorID  passenger_count  trip_distance  RatecodeID  payment_type  \
# 0               2                6           2.43           1             1
# 1               1                1           3.70           1             1
# 2               1                2           2.20           1             1
# 3               1                1           1.70           1             1
# 4               2                1           1.38           1             1
# ...           ...              ...            ...         ...           ...
# 6920925         2                1           7.83           1             1
# 6920926         2                1           2.50           1             1
# 6920927         2                1           1.68           1             1
# 6920928         2                1           2.65           1             1
# 6920929         1                1           2.10           1             1
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0               12.0    0.5      0.5        3.99           0.0
# 1               14.0    0.5      0.5        3.05           0.0
# 2               11.0    0.5      0.5        1.50           0.0
# 3                7.0    0.5      0.5        1.65           0.0
# 4                7.0    0.5      0.5        1.66           0.0
# ...              ...    ...      ...         ...           ...
# 6920925         29.0    0.5      0.5        5.00           0.0
# 6920926          9.5    0.5      0.5        2.16           0.0
# 6920927          7.0    0.5      0.5        1.00           0.0
# 6920928         11.0    0.5      0.5        1.00           0.0
# 6920929         11.5    0.0      0.5        2.45           0.0
#
#          improvement_surcharge  store_and_fwd_flag_N  store_and_fwd_flag_Y
# 0                          0.3                     1                     0
# 1                          0.3                     1                     0
# 2                          0.3                     1                     0
# 3                          0.3                     0                     1
# 4                          0.3                     1                     0
# ...                        ...                   ...                   ...
# 6920925                    0.3                     1                     0
# 6920926                    0.3                     1                     0
# 6920927                    0.3                     1                     0
# 6920928                    0.3                     1                     0
# 6920929                    0.3                     1                     0
#
# [6920930 rows x 13 columns]

# %%
X = X.head(1000000)

# %%
X.shape
# Out:
# (1000000, 13)

# %%
y = trip_data["tip_amount"].head(1000000)

# %%
y.shape
# Out:
# (1000000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
sklearn_rt = DecisionTreeRegressor(max_depth=8, random_state=42)

# %%
import time
t0 = time.time()
sklearn_rt.fit(X_train, y_train)
sklearn_time = time.time()-t0
print(sklearn_time)
# Out:
# 0.8940703868865967

# %%
from snapml import DecisionTreeRegressor

# %%
snapml_rt = DecisionTreeRegressor(max_depth=8, random_state=45, n_jobs=4)

# %%
t0 = time.time()
snapml_rt = snapml_rt.fit(X_train.to_numpy(), y_train.to_numpy())
snapml_time = time.time()-t0
print(snapml_time)
# Out:
# 0.14701437950134277
